# %% [markdown]
# > ### EEE4423: Deep Learning Lab
#
# # LAB #7: High-level Vision - Single Shot Object Detection (YOLO)

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2022-04-15 07:31:34.187577

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.01 slope for negative part - Note that it is different from the paper)
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.01   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.69 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])
        
        with open(list_file) as f:
            lines = f.readlines()
            
        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)
        
    def img_pre_process(self, img, boxes, labels):
        
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr
        
        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)
            
        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)
            
            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))
            
            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]
                
            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]
            
            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]
                
            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]
                
            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range
            
            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift
                
                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in
        
        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))
            
            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped
        
        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30)) 
        cell_size = 1./grid_size 

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2
        
        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel 
            ij = (cxcy_sample/cell_size).ceil()-1 
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1
            
            xy = ij*cell_size 
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size 
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy
            
        return target
    
    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr
        
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)
            
        target = self.generate_target(img, boxes, labels) # 7x7x30
        
        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1
        
        return img, target
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        
        self.pre_train_net = nn.Sequential(
            #conv1
            nn.Conv2d(3, 64, 7, stride=2, padding=3),
            nn.LeakyReLU(),
            nn.MaxPool2d(2, stride=2),
            #conv2
            nn.Conv2d(64, 192, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2, stride=2),
            #conv3
            nn.Conv2d(192, 128, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv4
            nn.Conv2d(128, 256, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv5
            nn.Conv2d(256, 256, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv6            
            nn.Conv2d(256, 512, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2, stride=2),
            #conv7
            nn.Conv2d(512, 256, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv8
            nn.Conv2d(256, 512, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv9
            nn.Conv2d(512, 256, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv10
            nn.Conv2d(256, 512, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv11
            nn.Conv2d(512, 256, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv12
            nn.Conv2d(256, 512, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv13
            nn.Conv2d(512, 256, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv14
            nn.Conv2d(256, 512, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv15
            nn.Conv2d(512, 512, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv16
            nn.Conv2d(512, 1024, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2,stride=2),
            #conv17
            nn.Conv2d(1024, 512, 1, stride=1, padding=0),
            nn.LeakyReLU(),
            #conv18
            nn.Conv2d(512, 1024, 3, stride=1, padding=1),
            nn.LeakyReLU(),
        )
        
        self.post_net = nn.Sequential(
            #conv19
            nn.Conv2d(1024, 1024, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv20
            nn.Conv2d(1024, 1024, 3, stride=2, padding=1),
            nn.LeakyReLU(),
            #conv21
            nn.Conv2d(1024, 1024, 3, stride=1, padding=1),
            nn.LeakyReLU(),
            #conv22
            nn.Conv2d(1024, 1024, 3, stride=1, padding=1),
            nn.LeakyReLU(),
        )
        
        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )
        
        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )
        
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()
        
        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj
    
    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        ###########
   
        ################data set 참고
        coord_pred = pred[contain].view(-1, 30)
        coord_target = target[contain].view(-1, 30)
        class_pred = coord_pred[:, 10:] 
        class_target = coord_target[:, 10:]  
        prob_loss = F.mse_loss(class_pred, class_target, size_average=False)
        ################
        
        return prob_loss
    
    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:, :, :, 4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        not_contain_pred = pred[not_contain].view(-1, 30)
        not_contain_target = target[not_contain].view(-1, 30)
                                                    
        not_contain_mask = torch.cuda.ByteTensor(not_contain_pred.size()).zero_().bool()
        not_contain_mask[:, 4] = 1
        not_contain_mask[:, 9] = 1 

        noobj_loss1 = F.mse_loss(not_contain_pred[not_contain_mask], not_contain_target[not_contain_mask], size_average=False)
        ################
        
        return noobj_loss1
    

    def contain_obj_error(self, pred, target): ##
        contain = target[:, :, :, 4] > 0 # [Batch_size, 7, 7]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping
        
        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)
        
        # Note that, We assign one predictor to be "responsible" for predicting 
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables
        
        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() 
        
        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence 
                                                                   # of the cell which contains object
        
        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            box_p_coord[:, :2] = box_p[:, :2]/7.0 - 0.5 * box_p[:, 2:4]
            box_p_coord[:, 2:4] = box_p[:, :2]/7.0 + 0.5 * box_p[:, 2:4]
            
            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:, :2] = box_t[:, :2]/7.0 - 0.5 * box_t[:, 2:4]
            box_t_coord[:, 2:4] =box_t[:, :2]/7.0 + 0.5 * box_t[:, 2:4]
            
            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4])
                                                      # compute IoU between prediction and target boxes, 
            
            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1
            
            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)
        
        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1, 5)
        
        ## For the cell which does not contain object
        not_contain_box_pred = box_target[contain_noobj_mask].view(-1, 5)

        ## For target domain 
        contain_box_target = box_target[contain_obj_mask].view(-1, 5)
        not_contain_box_target = box_target[contain_noobj_mask].view(-1, 5)
        not_contain_box_target[:,4] = 0
        
        ## For the GT IoU 
        contain_iou_target = target_iou_gt[contain_obj_mask[:,4]]

        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)
        
        return obj_loss, xy_loss, wh_loss, noobj_loss2
        
    def compute_iou(self, box_p, box_t):
        
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]
        
        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]
        
        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]
        
        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0 
        
        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)
        
        iou = inter_area / (pred_area + target_area - inter_area)
        
        return iou
    
        
    
    def forward(self,pred,target):
        batch_size = pred.size()[0]
        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
        
        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
        
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_root = '../dataset/lab07/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./misc/lab07/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('./pretrain/lab07/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])
print('pre_train_complete')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
        
    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)
        
        pred = model(images)
        loss = criterion(pred, target)
        
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:1.2956, average_loss: 1.4305
# Epoch [1/15], Iter [20,430] Loss:0.8833, average_loss: 1.3974
# Epoch [1/15], Iter [30,430] Loss:1.0108, average_loss: 1.3727
# Epoch [1/15], Iter [40,430] Loss:1.0572, average_loss: 1.3518
# Epoch [1/15], Iter [50,430] Loss:1.4283, average_loss: 1.3387
# Epoch [1/15], Iter [60,430] Loss:1.3189, average_loss: 1.3564
# Epoch [1/15], Iter [70,430] Loss:1.2327, average_loss: 1.3437
# Epoch [1/15], Iter [80,430] Loss:0.9458, average_loss: 1.3231
# Epoch [1/15], Iter [90,430] Loss:1.1214, average_loss: 1.3084
# Epoch [1/15], Iter [100,430] Loss:1.4570, average_loss: 1.3077
# Epoch [1/15], Iter [110,430] Loss:0.9777, average_loss: 1.2979
# Epoch [1/15], Iter [120,430] Loss:1.2764, average_loss: 1.2962
# Epoch [1/15], Iter [130,430] Loss:0.9094, average_loss: 1.3075
# Epoch [1/15], Iter [140,430] Loss:1.3308, average_loss: 1.2967
# Epoch [1/15], Iter [150,430] Loss:1.1179, average_loss: 1.2870
# Epoch [1/15], Iter [160,430] Loss:1.4170, average_loss: 1.2885
# Epoch [1/15], Iter [170,430] Loss:1.4253, average_loss: 1.2926
# Epoch [1/15], Iter [180,430] Loss:1.5226, average_loss: 1.2886
# Epoch [1/15], Iter [190,430] Loss:1.0918, average_loss: 1.2857
# Epoch [1/15], Iter [200,430] Loss:1.1988, average_loss: 1.2883
# Epoch [1/15], Iter [210,430] Loss:0.8036, average_loss: 1.2918
# Epoch [1/15], Iter [220,430] Loss:1.2920, average_loss: 1.2950
# Epoch [1/15], Iter [230,430] Loss:1.0898, average_loss: 1.3043
# Epoch [1/15], Iter [240,430] Loss:1.0423, average_loss: 1.3070
# Epoch [1/15], Iter [250,430] Loss:1.3938, average_loss: 1.3099
# Epoch [1/15], Iter [260,430] Loss:1.2368, average_loss: 1.3057
# Epoch [1/15], Iter [270,430] Loss:1.0324, average_loss: 1.3068
# Epoch [1/15], Iter [280,430] Loss:1.2051, average_loss: 1.3048
# Epoch [1/15], Iter [290,430] Loss:1.3444, average_loss: 1.3042
# Epoch [1/15], Iter [300,430] Loss:1.1864, average_loss: 1.3017
# Epoch [1/15], Iter [310,430] Loss:1.3005, average_loss: 1.3024
# Epoch [1/15], Iter [320,430] Loss:1.0579, average_loss: 1.3006
# Epoch [1/15], Iter [330,430] Loss:0.9520, average_loss: 1.2963
# Epoch [1/15], Iter [340,430] Loss:2.1820, average_loss: 1.2965
# Epoch [1/15], Iter [350,430] Loss:1.2306, average_loss: 1.2960
# Epoch [1/15], Iter [360,430] Loss:1.3948, average_loss: 1.2985
# Epoch [1/15], Iter [370,430] Loss:1.7820, average_loss: 1.2966
# Epoch [1/15], Iter [380,430] Loss:1.2277, average_loss: 1.2999
# Epoch [1/15], Iter [390,430] Loss:1.1265, average_loss: 1.3011
# Epoch [1/15], Iter [400,430] Loss:1.0067, average_loss: 1.2979
# Epoch [1/15], Iter [410,430] Loss:1.0123, average_loss: 1.2913
# Epoch [1/15], Iter [420,430] Loss:1.5906, average_loss: 1.2957
# Epoch [1/15], Iter [430,430] Loss:1.0660, average_loss: 1.2965
# Epoch [2/15], Iter [10,430] Loss:1.4662, average_loss: 1.1593
# Epoch [2/15], Iter [20,430] Loss:0.9083, average_loss: 1.2369
# Epoch [2/15], Iter [30,430] Loss:1.0094, average_loss: 1.2582
# Epoch [2/15], Iter [40,430] Loss:1.1899, average_loss: 1.2299
# Epoch [2/15], Iter [50,430] Loss:1.3581, average_loss: 1.2512
# Epoch [2/15], Iter [60,430] Loss:1.2906, average_loss: 1.2401
# Epoch [2/15], Iter [70,430] Loss:1.6162, average_loss: 1.2501
# Epoch [2/15], Iter [80,430] Loss:1.9233, average_loss: 1.2645
# Epoch [2/15], Iter [90,430] Loss:0.9749, average_loss: 1.2750
# Epoch [2/15], Iter [100,430] Loss:1.4216, average_loss: 1.2637
# Epoch [2/15], Iter [110,430] Loss:1.2335, average_loss: 1.2901
# Epoch [2/15], Iter [120,430] Loss:1.2945, average_loss: 1.2793
# Epoch [2/15], Iter [130,430] Loss:0.9144, average_loss: 1.2841
# Epoch [2/15], Iter [140,430] Loss:1.3975, average_loss: 1.2986
# Epoch [2/15], Iter [150,430] Loss:1.2284, average_loss: 1.3001
# Epoch [2/15], Iter [160,430] Loss:0.7620, average_loss: 1.2825
# Epoch [2/15], Iter [170,430] Loss:1.8886, average_loss: 1.2840
# Epoch [2/15], Iter [180,430] Loss:1.2389, average_loss: 1.2855
# Epoch [2/15], Iter [190,430] Loss:1.0929, average_loss: 1.2980
# Epoch [2/15], Iter [200,430] Loss:1.0682, average_loss: 1.3000
# Epoch [2/15], Iter [210,430] Loss:0.7029, average_loss: 1.2969
# Epoch [2/15], Iter [220,430] Loss:1.5105, average_loss: 1.2949
# Epoch [2/15], Iter [230,430] Loss:1.4898, average_loss: 1.2912
# Epoch [2/15], Iter [240,430] Loss:1.2240, average_loss: 1.2865
# Epoch [2/15], Iter [250,430] Loss:0.8698, average_loss: 1.2924
# Epoch [2/15], Iter [260,430] Loss:1.3348, average_loss: 1.2868
# Epoch [2/15], Iter [270,430] Loss:0.9181, average_loss: 1.2869
# Epoch [2/15], Iter [280,430] Loss:1.2590, average_loss: 1.2846
# Epoch [2/15], Iter [290,430] Loss:1.0044, average_loss: 1.2942
# Epoch [2/15], Iter [300,430] Loss:1.2035, average_loss: 1.2953
# Epoch [2/15], Iter [310,430] Loss:1.5632, average_loss: 1.2942
# Epoch [2/15], Iter [320,430] Loss:1.2104, average_loss: 1.2956
# Epoch [2/15], Iter [330,430] Loss:1.1484, average_loss: 1.2932
# Epoch [2/15], Iter [340,430] Loss:1.2370, average_loss: 1.2908
# Epoch [2/15], Iter [350,430] Loss:1.4464, average_loss: 1.2895
# Epoch [2/15], Iter [360,430] Loss:1.1786, average_loss: 1.2913
# Epoch [2/15], Iter [370,430] Loss:1.1810, average_loss: 1.2928
# Epoch [2/15], Iter [380,430] Loss:0.9213, average_loss: 1.2933
# Epoch [2/15], Iter [390,430] Loss:1.6907, average_loss: 1.2911
# Epoch [2/15], Iter [400,430] Loss:1.1040, average_loss: 1.2869
# Epoch [2/15], Iter [410,430] Loss:1.2654, average_loss: 1.2897
# Epoch [2/15], Iter [420,430] Loss:1.1993, average_loss: 1.2856
# Epoch [2/15], Iter [430,430] Loss:1.5413, average_loss: 1.2844
# Epoch [3/15], Iter [10,430] Loss:1.3011, average_loss: 1.1788
# Epoch [3/15], Iter [20,430] Loss:0.9912, average_loss: 1.1950
# Epoch [3/15], Iter [30,430] Loss:1.6480, average_loss: 1.2233
# Epoch [3/15], Iter [40,430] Loss:0.9186, average_loss: 1.2339
# Epoch [3/15], Iter [50,430] Loss:1.1195, average_loss: 1.2476
# Epoch [3/15], Iter [60,430] Loss:1.6855, average_loss: 1.2948
# Epoch [3/15], Iter [70,430] Loss:1.1742, average_loss: 1.2979
# Epoch [3/15], Iter [80,430] Loss:1.5681, average_loss: 1.2827
# Epoch [3/15], Iter [90,430] Loss:1.2997, average_loss: 1.2613
# Epoch [3/15], Iter [100,430] Loss:0.9753, average_loss: 1.2626
# Epoch [3/15], Iter [110,430] Loss:1.1958, average_loss: 1.2473
# Epoch [3/15], Iter [120,430] Loss:1.1095, average_loss: 1.2398
# Epoch [3/15], Iter [130,430] Loss:1.3700, average_loss: 1.2398
# Epoch [3/15], Iter [140,430] Loss:0.9275, average_loss: 1.2485
# Epoch [3/15], Iter [150,430] Loss:1.6150, average_loss: 1.2472
# Epoch [3/15], Iter [160,430] Loss:1.0557, average_loss: 1.2427
# Epoch [3/15], Iter [170,430] Loss:1.3623, average_loss: 1.2369
# Epoch [3/15], Iter [180,430] Loss:1.5724, average_loss: 1.2334
# Epoch [3/15], Iter [190,430] Loss:1.2236, average_loss: 1.2427
# Epoch [3/15], Iter [200,430] Loss:0.6887, average_loss: 1.2400
# Epoch [3/15], Iter [210,430] Loss:1.0593, average_loss: 1.2391
# Epoch [3/15], Iter [220,430] Loss:1.1147, average_loss: 1.2400
# Epoch [3/15], Iter [230,430] Loss:1.8509, average_loss: 1.2375
# Epoch [3/15], Iter [240,430] Loss:2.3739, average_loss: 1.2484
# Epoch [3/15], Iter [250,430] Loss:1.4022, average_loss: 1.2442
# Epoch [3/15], Iter [260,430] Loss:1.2012, average_loss: 1.2478
# Epoch [3/15], Iter [270,430] Loss:1.4396, average_loss: 1.2509
# Epoch [3/15], Iter [280,430] Loss:1.0184, average_loss: 1.2477
# Epoch [3/15], Iter [290,430] Loss:1.0875, average_loss: 1.2485
# Epoch [3/15], Iter [300,430] Loss:0.9942, average_loss: 1.2474
# Epoch [3/15], Iter [310,430] Loss:1.4147, average_loss: 1.2453
# Epoch [3/15], Iter [320,430] Loss:1.1151, average_loss: 1.2460
# Epoch [3/15], Iter [330,430] Loss:1.0943, average_loss: 1.2515
# Epoch [3/15], Iter [340,430] Loss:1.0115, average_loss: 1.2490
# Epoch [3/15], Iter [350,430] Loss:1.0056, average_loss: 1.2463
# Epoch [3/15], Iter [360,430] Loss:1.9712, average_loss: 1.2540
# Epoch [3/15], Iter [370,430] Loss:0.7422, average_loss: 1.2562
# Epoch [3/15], Iter [380,430] Loss:1.7551, average_loss: 1.2558
# Epoch [3/15], Iter [390,430] Loss:1.0403, average_loss: 1.2518
# Epoch [3/15], Iter [400,430] Loss:1.1819, average_loss: 1.2512
# Epoch [3/15], Iter [410,430] Loss:1.4060, average_loss: 1.2557
# Epoch [3/15], Iter [420,430] Loss:1.2763, average_loss: 1.2558
# Epoch [3/15], Iter [430,430] Loss:1.2156, average_loss: 1.2571
# Epoch [4/15], Iter [10,430] Loss:1.5087, average_loss: 1.2784
# Epoch [4/15], Iter [20,430] Loss:2.5590, average_loss: 1.3994
# Epoch [4/15], Iter [30,430] Loss:1.1254, average_loss: 1.3424
# Epoch [4/15], Iter [40,430] Loss:1.5156, average_loss: 1.3088
# Epoch [4/15], Iter [50,430] Loss:0.8920, average_loss: 1.3076
# Epoch [4/15], Iter [60,430] Loss:1.2637, average_loss: 1.3039
# Epoch [4/15], Iter [70,430] Loss:1.3879, average_loss: 1.2859
# Epoch [4/15], Iter [80,430] Loss:1.5440, average_loss: 1.2713
# Epoch [4/15], Iter [90,430] Loss:0.9541, average_loss: 1.2475
# Epoch [4/15], Iter [100,430] Loss:0.9271, average_loss: 1.2360
# Epoch [4/15], Iter [110,430] Loss:1.3892, average_loss: 1.2277
# Epoch [4/15], Iter [120,430] Loss:0.7399, average_loss: 1.2207
# Epoch [4/15], Iter [130,430] Loss:1.1854, average_loss: 1.2150
# Epoch [4/15], Iter [140,430] Loss:1.1244, average_loss: 1.2040
# Epoch [4/15], Iter [150,430] Loss:1.4624, average_loss: 1.2122
# Epoch [4/15], Iter [160,430] Loss:1.3488, average_loss: 1.2229
# Epoch [4/15], Iter [170,430] Loss:0.9739, average_loss: 1.2221
# Epoch [4/15], Iter [180,430] Loss:1.5312, average_loss: 1.2325
# Epoch [4/15], Iter [190,430] Loss:0.9235, average_loss: 1.2346
# Epoch [4/15], Iter [200,430] Loss:1.2218, average_loss: 1.2496
# Epoch [4/15], Iter [210,430] Loss:1.0356, average_loss: 1.2514
# Epoch [4/15], Iter [220,430] Loss:0.8683, average_loss: 1.2582
# Epoch [4/15], Iter [230,430] Loss:1.3336, average_loss: 1.2578
# Epoch [4/15], Iter [240,430] Loss:0.7714, average_loss: 1.2581
# Epoch [4/15], Iter [250,430] Loss:1.3241, average_loss: 1.2563
# Epoch [4/15], Iter [260,430] Loss:1.2359, average_loss: 1.2602
# Epoch [4/15], Iter [270,430] Loss:1.0802, average_loss: 1.2608
# Epoch [4/15], Iter [280,430] Loss:1.2736, average_loss: 1.2617
# Epoch [4/15], Iter [290,430] Loss:1.3041, average_loss: 1.2622
# Epoch [4/15], Iter [300,430] Loss:0.9490, average_loss: 1.2597
# Epoch [4/15], Iter [310,430] Loss:1.4391, average_loss: 1.2562
# Epoch [4/15], Iter [320,430] Loss:2.0232, average_loss: 1.2558
# Epoch [4/15], Iter [330,430] Loss:1.1699, average_loss: 1.2566
# Epoch [4/15], Iter [340,430] Loss:1.8541, average_loss: 1.2560
# Epoch [4/15], Iter [350,430] Loss:1.5230, average_loss: 1.2534
# Epoch [4/15], Iter [360,430] Loss:1.3065, average_loss: 1.2468
# Epoch [4/15], Iter [370,430] Loss:1.1063, average_loss: 1.2479
# Epoch [4/15], Iter [380,430] Loss:1.4432, average_loss: 1.2462
# Epoch [4/15], Iter [390,430] Loss:1.1006, average_loss: 1.2438
# Epoch [4/15], Iter [400,430] Loss:1.0885, average_loss: 1.2452
# Epoch [4/15], Iter [410,430] Loss:1.2039, average_loss: 1.2440
# Epoch [4/15], Iter [420,430] Loss:1.4173, average_loss: 1.2439
# Epoch [4/15], Iter [430,430] Loss:1.2440, average_loss: 1.2465
# Epoch [5/15], Iter [10,430] Loss:1.2513, average_loss: 1.3435
# Epoch [5/15], Iter [20,430] Loss:1.5345, average_loss: 1.3184
# Epoch [5/15], Iter [30,430] Loss:0.7871, average_loss: 1.3207
# Epoch [5/15], Iter [40,430] Loss:0.9420, average_loss: 1.2699
# Epoch [5/15], Iter [50,430] Loss:1.4129, average_loss: 1.2588
# Epoch [5/15], Iter [60,430] Loss:1.2735, average_loss: 1.2408
# Epoch [5/15], Iter [70,430] Loss:1.1859, average_loss: 1.2481
# Epoch [5/15], Iter [80,430] Loss:1.6240, average_loss: 1.2473
# Epoch [5/15], Iter [90,430] Loss:1.7349, average_loss: 1.2500
# Epoch [5/15], Iter [100,430] Loss:1.1560, average_loss: 1.2541
# Epoch [5/15], Iter [110,430] Loss:1.0919, average_loss: 1.2623
# Epoch [5/15], Iter [120,430] Loss:1.3319, average_loss: 1.2772
# Epoch [5/15], Iter [130,430] Loss:1.1372, average_loss: 1.2689
# Epoch [5/15], Iter [140,430] Loss:1.7078, average_loss: 1.2781
# Epoch [5/15], Iter [150,430] Loss:1.6415, average_loss: 1.2834
# Epoch [5/15], Iter [160,430] Loss:1.1015, average_loss: 1.2764
# Epoch [5/15], Iter [170,430] Loss:0.9520, average_loss: 1.2782
# Epoch [5/15], Iter [180,430] Loss:1.7554, average_loss: 1.2832
# Epoch [5/15], Iter [190,430] Loss:1.1761, average_loss: 1.2730
# Epoch [5/15], Iter [200,430] Loss:1.2665, average_loss: 1.2791
# Epoch [5/15], Iter [210,430] Loss:1.1534, average_loss: 1.2796
# Epoch [5/15], Iter [220,430] Loss:1.3038, average_loss: 1.2850
# Epoch [5/15], Iter [230,430] Loss:1.2420, average_loss: 1.2828
# Epoch [5/15], Iter [240,430] Loss:0.9432, average_loss: 1.2779
# Epoch [5/15], Iter [250,430] Loss:1.3529, average_loss: 1.2761
# Epoch [5/15], Iter [260,430] Loss:1.1009, average_loss: 1.2769
# Epoch [5/15], Iter [270,430] Loss:1.0766, average_loss: 1.2744
# Epoch [5/15], Iter [280,430] Loss:0.9946, average_loss: 1.2759
# Epoch [5/15], Iter [290,430] Loss:1.2058, average_loss: 1.2684
# Epoch [5/15], Iter [300,430] Loss:1.1500, average_loss: 1.2619
# Epoch [5/15], Iter [310,430] Loss:1.0033, average_loss: 1.2596
# Epoch [5/15], Iter [320,430] Loss:1.4281, average_loss: 1.2550
# Epoch [5/15], Iter [330,430] Loss:1.9019, average_loss: 1.2583
# Epoch [5/15], Iter [340,430] Loss:1.3175, average_loss: 1.2575
# Epoch [5/15], Iter [350,430] Loss:0.9302, average_loss: 1.2574
# Epoch [5/15], Iter [360,430] Loss:0.9649, average_loss: 1.2549
# Epoch [5/15], Iter [370,430] Loss:1.3392, average_loss: 1.2558
# Epoch [5/15], Iter [380,430] Loss:1.0575, average_loss: 1.2545
# Epoch [5/15], Iter [390,430] Loss:1.0308, average_loss: 1.2539
# Epoch [5/15], Iter [400,430] Loss:0.9390, average_loss: 1.2529
# Epoch [5/15], Iter [410,430] Loss:0.8399, average_loss: 1.2495
# Epoch [5/15], Iter [420,430] Loss:1.5772, average_loss: 1.2517
# Epoch [5/15], Iter [430,430] Loss:1.0568, average_loss: 1.2514
# Epoch [6/15], Iter [10,430] Loss:1.1214, average_loss: 1.1945
# Epoch [6/15], Iter [20,430] Loss:0.9324, average_loss: 1.1786
# Epoch [6/15], Iter [30,430] Loss:0.8251, average_loss: 1.1771
# Epoch [6/15], Iter [40,430] Loss:0.9012, average_loss: 1.1796
# Epoch [6/15], Iter [50,430] Loss:1.2507, average_loss: 1.1831
# Epoch [6/15], Iter [60,430] Loss:1.3135, average_loss: 1.2353
# Epoch [6/15], Iter [70,430] Loss:1.0561, average_loss: 1.2221
# Epoch [6/15], Iter [80,430] Loss:1.2214, average_loss: 1.2110
# Epoch [6/15], Iter [90,430] Loss:1.0890, average_loss: 1.2242
# Epoch [6/15], Iter [100,430] Loss:1.1241, average_loss: 1.2222
# Epoch [6/15], Iter [110,430] Loss:1.4785, average_loss: 1.2175
# Epoch [6/15], Iter [120,430] Loss:0.7713, average_loss: 1.2170
# Epoch [6/15], Iter [130,430] Loss:1.1795, average_loss: 1.2248
# Epoch [6/15], Iter [140,430] Loss:1.2734, average_loss: 1.2325
# Epoch [6/15], Iter [150,430] Loss:1.2817, average_loss: 1.2229
# Epoch [6/15], Iter [160,430] Loss:1.7968, average_loss: 1.2161
# Epoch [6/15], Iter [170,430] Loss:1.1474, average_loss: 1.2109
# Epoch [6/15], Iter [180,430] Loss:1.9475, average_loss: 1.2229
# Epoch [6/15], Iter [190,430] Loss:1.1269, average_loss: 1.2242
# Epoch [6/15], Iter [200,430] Loss:0.6772, average_loss: 1.2183
# Epoch [6/15], Iter [210,430] Loss:1.4501, average_loss: 1.2155
# Epoch [6/15], Iter [220,430] Loss:2.2986, average_loss: 1.2244
# Epoch [6/15], Iter [230,430] Loss:1.8929, average_loss: 1.2297
# Epoch [6/15], Iter [240,430] Loss:1.3178, average_loss: 1.2278
# Epoch [6/15], Iter [250,430] Loss:2.0704, average_loss: 1.2302
# Epoch [6/15], Iter [260,430] Loss:1.0079, average_loss: 1.2298
# Epoch [6/15], Iter [270,430] Loss:1.1519, average_loss: 1.2293
# Epoch [6/15], Iter [280,430] Loss:0.9128, average_loss: 1.2318
# Epoch [6/15], Iter [290,430] Loss:1.3537, average_loss: 1.2310
# Epoch [6/15], Iter [300,430] Loss:1.1276, average_loss: 1.2353
# Epoch [6/15], Iter [310,430] Loss:0.8179, average_loss: 1.2363
# Epoch [6/15], Iter [320,430] Loss:2.0526, average_loss: 1.2382
# Epoch [6/15], Iter [330,430] Loss:1.9029, average_loss: 1.2368
# Epoch [6/15], Iter [340,430] Loss:1.3199, average_loss: 1.2359
# Epoch [6/15], Iter [350,430] Loss:1.7544, average_loss: 1.2363
# Epoch [6/15], Iter [360,430] Loss:0.9154, average_loss: 1.2373
# Epoch [6/15], Iter [370,430] Loss:1.1220, average_loss: 1.2393
# Epoch [6/15], Iter [380,430] Loss:1.3304, average_loss: 1.2415
# Epoch [6/15], Iter [390,430] Loss:1.1314, average_loss: 1.2429
# Epoch [6/15], Iter [400,430] Loss:1.2097, average_loss: 1.2429
# Epoch [6/15], Iter [410,430] Loss:1.1209, average_loss: 1.2446
# Epoch [6/15], Iter [420,430] Loss:1.5912, average_loss: 1.2502
# Epoch [6/15], Iter [430,430] Loss:1.5542, average_loss: 1.2478
# Epoch [7/15], Iter [10,430] Loss:1.2861, average_loss: 1.2147
# Epoch [7/15], Iter [20,430] Loss:1.4991, average_loss: 1.2087
# Epoch [7/15], Iter [30,430] Loss:1.2975, average_loss: 1.2492
# Epoch [7/15], Iter [40,430] Loss:1.2569, average_loss: 1.2198
# Epoch [7/15], Iter [50,430] Loss:1.4468, average_loss: 1.2424
# Epoch [7/15], Iter [60,430] Loss:0.9779, average_loss: 1.2424
# Epoch [7/15], Iter [70,430] Loss:1.0526, average_loss: 1.2345
# Epoch [7/15], Iter [80,430] Loss:0.9797, average_loss: 1.2508
# Epoch [7/15], Iter [90,430] Loss:1.3737, average_loss: 1.2490
# Epoch [7/15], Iter [100,430] Loss:0.7871, average_loss: 1.2534
# Epoch [7/15], Iter [110,430] Loss:1.7435, average_loss: 1.2515
# Epoch [7/15], Iter [120,430] Loss:1.7013, average_loss: 1.2500
# Epoch [7/15], Iter [130,430] Loss:1.1008, average_loss: 1.2381
# Epoch [7/15], Iter [140,430] Loss:0.9332, average_loss: 1.2290
# Epoch [7/15], Iter [150,430] Loss:0.9789, average_loss: 1.2317
# Epoch [7/15], Iter [160,430] Loss:1.1112, average_loss: 1.2251
# Epoch [7/15], Iter [170,430] Loss:1.0165, average_loss: 1.2124
# Epoch [7/15], Iter [180,430] Loss:1.3248, average_loss: 1.2066
# Epoch [7/15], Iter [190,430] Loss:1.2525, average_loss: 1.2016
# Epoch [7/15], Iter [200,430] Loss:1.2213, average_loss: 1.2058
# Epoch [7/15], Iter [210,430] Loss:0.8947, average_loss: 1.2045
# Epoch [7/15], Iter [220,430] Loss:1.2560, average_loss: 1.2049
# Epoch [7/15], Iter [230,430] Loss:1.1721, average_loss: 1.2005
# Epoch [7/15], Iter [240,430] Loss:0.9783, average_loss: 1.2017
# Epoch [7/15], Iter [250,430] Loss:1.0802, average_loss: 1.2034
# Epoch [7/15], Iter [260,430] Loss:0.9844, average_loss: 1.2024
# Epoch [7/15], Iter [270,430] Loss:1.1951, average_loss: 1.1988
# Epoch [7/15], Iter [280,430] Loss:1.0293, average_loss: 1.1952
# Epoch [7/15], Iter [290,430] Loss:1.3484, average_loss: 1.1956
# Epoch [7/15], Iter [300,430] Loss:0.9425, average_loss: 1.1950
# Epoch [7/15], Iter [310,430] Loss:2.0137, average_loss: 1.2028
# Epoch [7/15], Iter [320,430] Loss:1.3344, average_loss: 1.2058
# Epoch [7/15], Iter [330,430] Loss:0.8822, average_loss: 1.2069
# Epoch [7/15], Iter [340,430] Loss:0.8940, average_loss: 1.2036
# Epoch [7/15], Iter [350,430] Loss:1.3712, average_loss: 1.2058
# Epoch [7/15], Iter [360,430] Loss:1.5243, average_loss: 1.2078
# Epoch [7/15], Iter [370,430] Loss:1.2984, average_loss: 1.2080
# Epoch [7/15], Iter [380,430] Loss:1.0138, average_loss: 1.2055
# Epoch [7/15], Iter [390,430] Loss:1.7259, average_loss: 1.2086
# Epoch [7/15], Iter [400,430] Loss:1.5280, average_loss: 1.2145
# Epoch [7/15], Iter [410,430] Loss:1.5146, average_loss: 1.2133
# Epoch [7/15], Iter [420,430] Loss:0.9946, average_loss: 1.2161
# Epoch [7/15], Iter [430,430] Loss:1.1030, average_loss: 1.2149
# Epoch [8/15], Iter [10,430] Loss:0.9626, average_loss: 1.3647
# Epoch [8/15], Iter [20,430] Loss:1.3781, average_loss: 1.3691
# Epoch [8/15], Iter [30,430] Loss:1.2845, average_loss: 1.2916
# Epoch [8/15], Iter [40,430] Loss:1.2886, average_loss: 1.2441
# Epoch [8/15], Iter [50,430] Loss:1.3064, average_loss: 1.2389
# Epoch [8/15], Iter [60,430] Loss:1.4740, average_loss: 1.2644
# Epoch [8/15], Iter [70,430] Loss:1.6074, average_loss: 1.2580
# Epoch [8/15], Iter [80,430] Loss:0.8070, average_loss: 1.2453
# Epoch [8/15], Iter [90,430] Loss:0.7872, average_loss: 1.2602
# Epoch [8/15], Iter [100,430] Loss:1.2668, average_loss: 1.2517
# Epoch [8/15], Iter [110,430] Loss:0.9568, average_loss: 1.2584
# Epoch [8/15], Iter [120,430] Loss:1.4205, average_loss: 1.2586
# Epoch [8/15], Iter [130,430] Loss:0.9316, average_loss: 1.2386
# Epoch [8/15], Iter [140,430] Loss:1.2084, average_loss: 1.2306
# Epoch [8/15], Iter [150,430] Loss:1.1720, average_loss: 1.2230
# Epoch [8/15], Iter [160,430] Loss:0.9937, average_loss: 1.2323
# Epoch [8/15], Iter [170,430] Loss:1.4092, average_loss: 1.2331
# Epoch [8/15], Iter [180,430] Loss:1.5938, average_loss: 1.2345
# Epoch [8/15], Iter [190,430] Loss:1.4039, average_loss: 1.2341
# Epoch [8/15], Iter [200,430] Loss:1.2232, average_loss: 1.2293
# Epoch [8/15], Iter [210,430] Loss:0.8576, average_loss: 1.2262
# Epoch [8/15], Iter [220,430] Loss:1.5907, average_loss: 1.2366
# Epoch [8/15], Iter [230,430] Loss:1.1601, average_loss: 1.2394
# Epoch [8/15], Iter [240,430] Loss:1.0456, average_loss: 1.2301
# Epoch [8/15], Iter [250,430] Loss:1.9025, average_loss: 1.2316
# Epoch [8/15], Iter [260,430] Loss:1.5257, average_loss: 1.2333
# Epoch [8/15], Iter [270,430] Loss:1.3929, average_loss: 1.2299
# Epoch [8/15], Iter [280,430] Loss:1.2775, average_loss: 1.2295
# Epoch [8/15], Iter [290,430] Loss:1.4279, average_loss: 1.2327
# Epoch [8/15], Iter [300,430] Loss:0.9927, average_loss: 1.2350
# Epoch [8/15], Iter [310,430] Loss:0.9851, average_loss: 1.2338
# Epoch [8/15], Iter [320,430] Loss:1.6446, average_loss: 1.2349
# Epoch [8/15], Iter [330,430] Loss:0.7786, average_loss: 1.2357
# Epoch [8/15], Iter [340,430] Loss:1.2148, average_loss: 1.2343
# Epoch [8/15], Iter [350,430] Loss:0.9173, average_loss: 1.2332
# Epoch [8/15], Iter [360,430] Loss:1.5646, average_loss: 1.2342
# Epoch [8/15], Iter [370,430] Loss:1.1772, average_loss: 1.2336
# Epoch [8/15], Iter [380,430] Loss:0.9555, average_loss: 1.2295
# Epoch [8/15], Iter [390,430] Loss:0.9926, average_loss: 1.2261
# Epoch [8/15], Iter [400,430] Loss:1.0266, average_loss: 1.2231
# Epoch [8/15], Iter [410,430] Loss:0.9077, average_loss: 1.2238
# Epoch [8/15], Iter [420,430] Loss:1.0617, average_loss: 1.2262
# Epoch [8/15], Iter [430,430] Loss:1.3315, average_loss: 1.2265
# Epoch [9/15], Iter [10,430] Loss:1.8461, average_loss: 1.2861
# Epoch [9/15], Iter [20,430] Loss:0.9275, average_loss: 1.2806
# Epoch [9/15], Iter [30,430] Loss:0.8921, average_loss: 1.2103
# Epoch [9/15], Iter [40,430] Loss:0.8449, average_loss: 1.1737
# Epoch [9/15], Iter [50,430] Loss:1.5736, average_loss: 1.1894
# Epoch [9/15], Iter [60,430] Loss:2.4919, average_loss: 1.2038
# Epoch [9/15], Iter [70,430] Loss:1.1004, average_loss: 1.2213
# Epoch [9/15], Iter [80,430] Loss:0.7903, average_loss: 1.2206
# Epoch [9/15], Iter [90,430] Loss:1.0170, average_loss: 1.2170
# Epoch [9/15], Iter [100,430] Loss:0.9251, average_loss: 1.2102
# Epoch [9/15], Iter [110,430] Loss:0.9684, average_loss: 1.2107
# Epoch [9/15], Iter [120,430] Loss:1.1066, average_loss: 1.2046
# Epoch [9/15], Iter [130,430] Loss:1.2441, average_loss: 1.2032
# Epoch [9/15], Iter [140,430] Loss:0.9730, average_loss: 1.2072
# Epoch [9/15], Iter [150,430] Loss:1.8523, average_loss: 1.2231
# Epoch [9/15], Iter [160,430] Loss:1.4059, average_loss: 1.2242
# Epoch [9/15], Iter [170,430] Loss:0.7948, average_loss: 1.2144
# Epoch [9/15], Iter [180,430] Loss:0.9260, average_loss: 1.2263
# Epoch [9/15], Iter [190,430] Loss:1.0061, average_loss: 1.2183
# Epoch [9/15], Iter [200,430] Loss:0.9293, average_loss: 1.2165
# Epoch [9/15], Iter [210,430] Loss:0.9323, average_loss: 1.2152
# Epoch [9/15], Iter [220,430] Loss:1.0025, average_loss: 1.2204
# Epoch [9/15], Iter [230,430] Loss:0.8649, average_loss: 1.2221
# Epoch [9/15], Iter [240,430] Loss:1.0473, average_loss: 1.2246
# Epoch [9/15], Iter [250,430] Loss:1.0671, average_loss: 1.2277
# Epoch [9/15], Iter [260,430] Loss:0.9924, average_loss: 1.2239
# Epoch [9/15], Iter [270,430] Loss:1.0098, average_loss: 1.2217
# Epoch [9/15], Iter [280,430] Loss:1.0353, average_loss: 1.2234
# Epoch [9/15], Iter [290,430] Loss:2.0186, average_loss: 1.2200
# Epoch [9/15], Iter [300,430] Loss:0.9605, average_loss: 1.2207
# Epoch [9/15], Iter [310,430] Loss:1.7778, average_loss: 1.2230
# Epoch [9/15], Iter [320,430] Loss:1.5168, average_loss: 1.2252
# Epoch [9/15], Iter [330,430] Loss:1.8873, average_loss: 1.2248
# Epoch [9/15], Iter [340,430] Loss:0.9486, average_loss: 1.2229
# Epoch [9/15], Iter [350,430] Loss:1.3179, average_loss: 1.2209
# Epoch [9/15], Iter [360,430] Loss:1.4407, average_loss: 1.2258
# Epoch [9/15], Iter [370,430] Loss:1.1435, average_loss: 1.2248
# Epoch [9/15], Iter [380,430] Loss:1.0358, average_loss: 1.2239
# Epoch [9/15], Iter [390,430] Loss:1.4900, average_loss: 1.2254
# Epoch [9/15], Iter [400,430] Loss:1.3633, average_loss: 1.2231
# Epoch [9/15], Iter [410,430] Loss:1.5153, average_loss: 1.2209
# Epoch [9/15], Iter [420,430] Loss:1.0945, average_loss: 1.2156
# Epoch [9/15], Iter [430,430] Loss:1.4790, average_loss: 1.2170
# Epoch [10/15], Iter [10,430] Loss:0.8748, average_loss: 1.1362
# Epoch [10/15], Iter [20,430] Loss:0.9128, average_loss: 1.1199
# Epoch [10/15], Iter [30,430] Loss:1.0445, average_loss: 1.1228
# Epoch [10/15], Iter [40,430] Loss:1.5501, average_loss: 1.1344
# Epoch [10/15], Iter [50,430] Loss:0.9864, average_loss: 1.1435
# Epoch [10/15], Iter [60,430] Loss:0.9678, average_loss: 1.1761
# Epoch [10/15], Iter [70,430] Loss:0.9466, average_loss: 1.1518
# Epoch [10/15], Iter [80,430] Loss:1.7279, average_loss: 1.1816
# Epoch [10/15], Iter [90,430] Loss:1.5002, average_loss: 1.1894
# Epoch [10/15], Iter [100,430] Loss:1.0534, average_loss: 1.1857
# Epoch [10/15], Iter [110,430] Loss:1.4046, average_loss: 1.1803
# Epoch [10/15], Iter [120,430] Loss:0.8338, average_loss: 1.1795
# Epoch [10/15], Iter [130,430] Loss:1.2904, average_loss: 1.1823
# Epoch [10/15], Iter [140,430] Loss:0.8315, average_loss: 1.1905
# Epoch [10/15], Iter [150,430] Loss:1.0215, average_loss: 1.2036
# Epoch [10/15], Iter [160,430] Loss:1.4193, average_loss: 1.1942
# Epoch [10/15], Iter [170,430] Loss:0.9295, average_loss: 1.1988
# Epoch [10/15], Iter [180,430] Loss:0.7693, average_loss: 1.1997
# Epoch [10/15], Iter [190,430] Loss:1.3028, average_loss: 1.2038
# Epoch [10/15], Iter [200,430] Loss:1.3159, average_loss: 1.2013
# Epoch [10/15], Iter [210,430] Loss:1.0790, average_loss: 1.2019
# Epoch [10/15], Iter [220,430] Loss:1.0407, average_loss: 1.2024
# Epoch [10/15], Iter [230,430] Loss:1.3596, average_loss: 1.2028
# Epoch [10/15], Iter [240,430] Loss:1.1009, average_loss: 1.2062
# Epoch [10/15], Iter [250,430] Loss:1.0388, average_loss: 1.2077
# Epoch [10/15], Iter [260,430] Loss:1.1614, average_loss: 1.2030
# Epoch [10/15], Iter [270,430] Loss:1.5868, average_loss: 1.2040
# Epoch [10/15], Iter [280,430] Loss:1.1058, average_loss: 1.2014
# Epoch [10/15], Iter [290,430] Loss:1.1751, average_loss: 1.1968
# Epoch [10/15], Iter [300,430] Loss:1.0670, average_loss: 1.2025
# Epoch [10/15], Iter [310,430] Loss:1.5368, average_loss: 1.2036
# Epoch [10/15], Iter [320,430] Loss:1.1957, average_loss: 1.2115
# Epoch [10/15], Iter [330,430] Loss:1.8852, average_loss: 1.2136
# Epoch [10/15], Iter [340,430] Loss:1.5236, average_loss: 1.2151
# Epoch [10/15], Iter [350,430] Loss:1.4279, average_loss: 1.2188
# Epoch [10/15], Iter [360,430] Loss:1.0662, average_loss: 1.2224
# Epoch [10/15], Iter [370,430] Loss:0.9824, average_loss: 1.2192
# Epoch [10/15], Iter [380,430] Loss:1.7755, average_loss: 1.2189
# Epoch [10/15], Iter [390,430] Loss:1.4244, average_loss: 1.2184
# Epoch [10/15], Iter [400,430] Loss:1.0015, average_loss: 1.2240
# Epoch [10/15], Iter [410,430] Loss:1.2714, average_loss: 1.2212
# Epoch [10/15], Iter [420,430] Loss:1.2208, average_loss: 1.2199
# Epoch [10/15], Iter [430,430] Loss:1.3773, average_loss: 1.2229
# Epoch [11/15], Iter [10,430] Loss:0.9913, average_loss: 0.9683
# Epoch [11/15], Iter [20,430] Loss:1.0231, average_loss: 1.0922
# Epoch [11/15], Iter [30,430] Loss:1.7542, average_loss: 1.1015
# Epoch [11/15], Iter [40,430] Loss:0.9292, average_loss: 1.1280
# Epoch [11/15], Iter [50,430] Loss:1.0627, average_loss: 1.1349
# Epoch [11/15], Iter [60,430] Loss:0.9739, average_loss: 1.1655
# Epoch [11/15], Iter [70,430] Loss:1.0950, average_loss: 1.1665
# Epoch [11/15], Iter [80,430] Loss:1.3960, average_loss: 1.1789
# Epoch [11/15], Iter [90,430] Loss:1.0520, average_loss: 1.1691
# Epoch [11/15], Iter [100,430] Loss:1.1135, average_loss: 1.1659
# Epoch [11/15], Iter [110,430] Loss:1.1338, average_loss: 1.1776
# Epoch [11/15], Iter [120,430] Loss:1.3290, average_loss: 1.1852
# Epoch [11/15], Iter [130,430] Loss:1.2315, average_loss: 1.1778
# Epoch [11/15], Iter [140,430] Loss:0.8830, average_loss: 1.1839
# Epoch [11/15], Iter [150,430] Loss:1.2410, average_loss: 1.1968
# Epoch [11/15], Iter [160,430] Loss:1.2564, average_loss: 1.1942
# Epoch [11/15], Iter [170,430] Loss:0.9951, average_loss: 1.1984
# Epoch [11/15], Iter [180,430] Loss:1.8776, average_loss: 1.1973
# Epoch [11/15], Iter [190,430] Loss:1.1209, average_loss: 1.2099
# Epoch [11/15], Iter [200,430] Loss:0.9888, average_loss: 1.2062
# Epoch [11/15], Iter [210,430] Loss:1.1699, average_loss: 1.2108
# Epoch [11/15], Iter [220,430] Loss:1.2314, average_loss: 1.2188
# Epoch [11/15], Iter [230,430] Loss:1.5722, average_loss: 1.2199
# Epoch [11/15], Iter [240,430] Loss:2.6716, average_loss: 1.2292
# Epoch [11/15], Iter [250,430] Loss:1.7061, average_loss: 1.2283
# Epoch [11/15], Iter [260,430] Loss:0.9721, average_loss: 1.2307
# Epoch [11/15], Iter [270,430] Loss:1.3021, average_loss: 1.2314
# Epoch [11/15], Iter [280,430] Loss:1.2422, average_loss: 1.2247
# Epoch [11/15], Iter [290,430] Loss:1.0556, average_loss: 1.2194
# Epoch [11/15], Iter [300,430] Loss:1.1501, average_loss: 1.2161
# Epoch [11/15], Iter [310,430] Loss:1.2862, average_loss: 1.2210
# Epoch [11/15], Iter [320,430] Loss:1.4738, average_loss: 1.2229
# Epoch [11/15], Iter [330,430] Loss:0.7589, average_loss: 1.2195
# Epoch [11/15], Iter [340,430] Loss:0.7369, average_loss: 1.2232
# Epoch [11/15], Iter [350,430] Loss:0.8743, average_loss: 1.2217
# Epoch [11/15], Iter [360,430] Loss:1.0101, average_loss: 1.2217
# Epoch [11/15], Iter [370,430] Loss:1.7504, average_loss: 1.2255
# Epoch [11/15], Iter [380,430] Loss:1.3117, average_loss: 1.2307
# Epoch [11/15], Iter [390,430] Loss:1.0649, average_loss: 1.2261
# Epoch [11/15], Iter [400,430] Loss:1.1961, average_loss: 1.2247
# Epoch [11/15], Iter [410,430] Loss:0.9000, average_loss: 1.2251
# Epoch [11/15], Iter [420,430] Loss:1.0488, average_loss: 1.2248
# Epoch [11/15], Iter [430,430] Loss:1.2088, average_loss: 1.2268
# Epoch [12/15], Iter [10,430] Loss:1.2111, average_loss: 1.3874
# Epoch [12/15], Iter [20,430] Loss:1.0595, average_loss: 1.2297
# Epoch [12/15], Iter [30,430] Loss:0.9434, average_loss: 1.1865
# Epoch [12/15], Iter [40,430] Loss:2.1627, average_loss: 1.2525
# Epoch [12/15], Iter [50,430] Loss:1.4139, average_loss: 1.2625
# Epoch [12/15], Iter [60,430] Loss:1.8360, average_loss: 1.2663
# Epoch [12/15], Iter [70,430] Loss:1.4907, average_loss: 1.2773
# Epoch [12/15], Iter [80,430] Loss:0.8116, average_loss: 1.2658
# Epoch [12/15], Iter [90,430] Loss:0.9095, average_loss: 1.2569
# Epoch [12/15], Iter [100,430] Loss:1.1151, average_loss: 1.2384
# Epoch [12/15], Iter [110,430] Loss:0.6954, average_loss: 1.2376
# Epoch [12/15], Iter [120,430] Loss:0.9482, average_loss: 1.2327
# Epoch [12/15], Iter [130,430] Loss:0.8512, average_loss: 1.2317
# Epoch [12/15], Iter [140,430] Loss:1.3053, average_loss: 1.2322
# Epoch [12/15], Iter [150,430] Loss:1.0847, average_loss: 1.2295
# Epoch [12/15], Iter [160,430] Loss:1.2233, average_loss: 1.2237
# Epoch [12/15], Iter [170,430] Loss:1.3241, average_loss: 1.2146
# Epoch [12/15], Iter [180,430] Loss:1.1530, average_loss: 1.2174
# Epoch [12/15], Iter [190,430] Loss:1.7189, average_loss: 1.2161
# Epoch [12/15], Iter [200,430] Loss:1.1605, average_loss: 1.2201
# Epoch [12/15], Iter [210,430] Loss:1.1389, average_loss: 1.2228
# Epoch [12/15], Iter [220,430] Loss:1.1984, average_loss: 1.2256
# Epoch [12/15], Iter [230,430] Loss:1.2870, average_loss: 1.2248
# Epoch [12/15], Iter [240,430] Loss:0.9586, average_loss: 1.2203
# Epoch [12/15], Iter [250,430] Loss:1.3436, average_loss: 1.2189
# Epoch [12/15], Iter [260,430] Loss:1.4873, average_loss: 1.2147
# Epoch [12/15], Iter [270,430] Loss:1.1417, average_loss: 1.2138
# Epoch [12/15], Iter [280,430] Loss:1.2468, average_loss: 1.2165
# Epoch [12/15], Iter [290,430] Loss:1.1017, average_loss: 1.2237
# Epoch [12/15], Iter [300,430] Loss:1.7898, average_loss: 1.2268
# Epoch [12/15], Iter [310,430] Loss:1.2478, average_loss: 1.2310
# Epoch [12/15], Iter [320,430] Loss:1.0264, average_loss: 1.2283
# Epoch [12/15], Iter [330,430] Loss:1.6232, average_loss: 1.2263
# Epoch [12/15], Iter [340,430] Loss:1.2472, average_loss: 1.2291
# Epoch [12/15], Iter [350,430] Loss:1.5624, average_loss: 1.2306
# Epoch [12/15], Iter [360,430] Loss:1.1652, average_loss: 1.2328
# Epoch [12/15], Iter [370,430] Loss:1.2889, average_loss: 1.2343
# Epoch [12/15], Iter [380,430] Loss:1.4172, average_loss: 1.2322
# Epoch [12/15], Iter [390,430] Loss:1.0397, average_loss: 1.2348
# Epoch [12/15], Iter [400,430] Loss:0.8548, average_loss: 1.2344
# Epoch [12/15], Iter [410,430] Loss:1.1708, average_loss: 1.2298
# Epoch [12/15], Iter [420,430] Loss:0.9743, average_loss: 1.2263
# Epoch [12/15], Iter [430,430] Loss:1.2153, average_loss: 1.2246
# Epoch [13/15], Iter [10,430] Loss:1.4835, average_loss: 1.3186
# Epoch [13/15], Iter [20,430] Loss:0.8833, average_loss: 1.2813
# Epoch [13/15], Iter [30,430] Loss:1.2623, average_loss: 1.2766
# Epoch [13/15], Iter [40,430] Loss:0.9566, average_loss: 1.2508
# Epoch [13/15], Iter [50,430] Loss:1.4828, average_loss: 1.2244
# Epoch [13/15], Iter [60,430] Loss:1.1755, average_loss: 1.2244
# Epoch [13/15], Iter [70,430] Loss:1.1709, average_loss: 1.2333
# Epoch [13/15], Iter [80,430] Loss:0.9593, average_loss: 1.2431
# Epoch [13/15], Iter [90,430] Loss:0.8570, average_loss: 1.2441
# Epoch [13/15], Iter [100,430] Loss:1.2183, average_loss: 1.2331
# Epoch [13/15], Iter [110,430] Loss:1.2692, average_loss: 1.2211
# Epoch [13/15], Iter [120,430] Loss:1.0205, average_loss: 1.2157
# Epoch [13/15], Iter [130,430] Loss:2.0129, average_loss: 1.2048
# Epoch [13/15], Iter [140,430] Loss:1.4263, average_loss: 1.2017
# Epoch [13/15], Iter [150,430] Loss:1.1057, average_loss: 1.1983
# Epoch [13/15], Iter [160,430] Loss:1.3170, average_loss: 1.2056
# Epoch [13/15], Iter [170,430] Loss:1.3724, average_loss: 1.2056
# Epoch [13/15], Iter [180,430] Loss:0.7551, average_loss: 1.2057
# Epoch [13/15], Iter [190,430] Loss:0.7858, average_loss: 1.2104
# Epoch [13/15], Iter [200,430] Loss:1.2269, average_loss: 1.2102
# Epoch [13/15], Iter [210,430] Loss:0.9941, average_loss: 1.2071
# Epoch [13/15], Iter [220,430] Loss:1.2162, average_loss: 1.2081
# Epoch [13/15], Iter [230,430] Loss:1.3052, average_loss: 1.1998
# Epoch [13/15], Iter [240,430] Loss:1.3161, average_loss: 1.2046
# Epoch [13/15], Iter [250,430] Loss:0.9138, average_loss: 1.2028
# Epoch [13/15], Iter [260,430] Loss:1.4543, average_loss: 1.2012
# Epoch [13/15], Iter [270,430] Loss:0.7774, average_loss: 1.2019
# Epoch [13/15], Iter [280,430] Loss:0.9831, average_loss: 1.1987
# Epoch [13/15], Iter [290,430] Loss:0.8509, average_loss: 1.1992
# Epoch [13/15], Iter [300,430] Loss:1.7958, average_loss: 1.2036
# Epoch [13/15], Iter [310,430] Loss:1.1623, average_loss: 1.2080
# Epoch [13/15], Iter [320,430] Loss:1.1897, average_loss: 1.2111
# Epoch [13/15], Iter [330,430] Loss:0.9104, average_loss: 1.2065
# Epoch [13/15], Iter [340,430] Loss:0.9904, average_loss: 1.2096
# Epoch [13/15], Iter [350,430] Loss:1.3534, average_loss: 1.2072
# Epoch [13/15], Iter [360,430] Loss:1.1491, average_loss: 1.2101
# Epoch [13/15], Iter [370,430] Loss:1.0695, average_loss: 1.2069
# Epoch [13/15], Iter [380,430] Loss:1.2868, average_loss: 1.2049
# Epoch [13/15], Iter [390,430] Loss:1.4487, average_loss: 1.2053
# Epoch [13/15], Iter [400,430] Loss:1.1067, average_loss: 1.2082
# Epoch [13/15], Iter [410,430] Loss:1.3564, average_loss: 1.2052
# Epoch [13/15], Iter [420,430] Loss:0.8427, average_loss: 1.2037
# Epoch [13/15], Iter [430,430] Loss:1.6658, average_loss: 1.2071
# Epoch [14/15], Iter [10,430] Loss:1.0622, average_loss: 1.1810
# Epoch [14/15], Iter [20,430] Loss:0.8581, average_loss: 1.1279
# Epoch [14/15], Iter [30,430] Loss:1.1807, average_loss: 1.1368
# Epoch [14/15], Iter [40,430] Loss:1.4471, average_loss: 1.1500
# Epoch [14/15], Iter [50,430] Loss:0.8667, average_loss: 1.1705
# Epoch [14/15], Iter [60,430] Loss:1.3255, average_loss: 1.1792
# Epoch [14/15], Iter [70,430] Loss:1.2082, average_loss: 1.1972
# Epoch [14/15], Iter [80,430] Loss:1.9704, average_loss: 1.2214
# Epoch [14/15], Iter [90,430] Loss:1.1129, average_loss: 1.2144
# Epoch [14/15], Iter [100,430] Loss:1.0845, average_loss: 1.2083
# Epoch [14/15], Iter [110,430] Loss:1.1022, average_loss: 1.2171
# Epoch [14/15], Iter [120,430] Loss:1.2070, average_loss: 1.2157
# Epoch [14/15], Iter [130,430] Loss:1.5938, average_loss: 1.2150
# Epoch [14/15], Iter [140,430] Loss:1.1811, average_loss: 1.2090
# Epoch [14/15], Iter [150,430] Loss:1.1576, average_loss: 1.2140
# Epoch [14/15], Iter [160,430] Loss:0.8332, average_loss: 1.2057
# Epoch [14/15], Iter [170,430] Loss:0.8005, average_loss: 1.2081
# Epoch [14/15], Iter [180,430] Loss:0.8255, average_loss: 1.2060
# Epoch [14/15], Iter [190,430] Loss:1.1456, average_loss: 1.2018
# Epoch [14/15], Iter [200,430] Loss:0.8645, average_loss: 1.2000
# Epoch [14/15], Iter [210,430] Loss:0.9441, average_loss: 1.1961
# Epoch [14/15], Iter [220,430] Loss:1.1290, average_loss: 1.1968
# Epoch [14/15], Iter [230,430] Loss:1.0458, average_loss: 1.1920
# Epoch [14/15], Iter [240,430] Loss:1.1875, average_loss: 1.1892
# Epoch [14/15], Iter [250,430] Loss:1.7793, average_loss: 1.1895
# Epoch [14/15], Iter [260,430] Loss:1.8293, average_loss: 1.1967
# Epoch [14/15], Iter [270,430] Loss:1.2690, average_loss: 1.1943
# Epoch [14/15], Iter [280,430] Loss:1.2943, average_loss: 1.1916
# Epoch [14/15], Iter [290,430] Loss:0.9465, average_loss: 1.1886
# Epoch [14/15], Iter [300,430] Loss:1.3378, average_loss: 1.1879
# Epoch [14/15], Iter [310,430] Loss:1.4646, average_loss: 1.1879
# Epoch [14/15], Iter [320,430] Loss:1.3504, average_loss: 1.1933
# Epoch [14/15], Iter [330,430] Loss:1.7070, average_loss: 1.1936
# Epoch [14/15], Iter [340,430] Loss:1.6336, average_loss: 1.1969
# Epoch [14/15], Iter [350,430] Loss:1.3757, average_loss: 1.1984
# Epoch [14/15], Iter [360,430] Loss:1.2471, average_loss: 1.2003
# Epoch [14/15], Iter [370,430] Loss:1.2473, average_loss: 1.2027
# Epoch [14/15], Iter [380,430] Loss:0.8819, average_loss: 1.2051
# Epoch [14/15], Iter [390,430] Loss:0.9712, average_loss: 1.2028
# Epoch [14/15], Iter [400,430] Loss:2.0959, average_loss: 1.2010
# Epoch [14/15], Iter [410,430] Loss:1.6158, average_loss: 1.2000
# Epoch [14/15], Iter [420,430] Loss:1.5825, average_loss: 1.1990
# Epoch [14/15], Iter [430,430] Loss:0.9675, average_loss: 1.2006
# Epoch [15/15], Iter [10,430] Loss:1.8920, average_loss: 1.4329
# Epoch [15/15], Iter [20,430] Loss:1.3590, average_loss: 1.3000
# Epoch [15/15], Iter [30,430] Loss:1.1148, average_loss: 1.2404
# Epoch [15/15], Iter [40,430] Loss:0.7741, average_loss: 1.2458
# Epoch [15/15], Iter [50,430] Loss:0.8554, average_loss: 1.2252
# Epoch [15/15], Iter [60,430] Loss:1.3891, average_loss: 1.2371
# Epoch [15/15], Iter [70,430] Loss:0.9176, average_loss: 1.2497
# Epoch [15/15], Iter [80,430] Loss:1.1764, average_loss: 1.2412
# Epoch [15/15], Iter [90,430] Loss:0.9218, average_loss: 1.2141
# Epoch [15/15], Iter [100,430] Loss:1.1492, average_loss: 1.2210
# Epoch [15/15], Iter [110,430] Loss:1.1593, average_loss: 1.2192
# Epoch [15/15], Iter [120,430] Loss:0.8130, average_loss: 1.2170
# Epoch [15/15], Iter [130,430] Loss:0.9515, average_loss: 1.2100
# Epoch [15/15], Iter [140,430] Loss:2.2631, average_loss: 1.2110
# Epoch [15/15], Iter [150,430] Loss:1.2634, average_loss: 1.2119
# Epoch [15/15], Iter [160,430] Loss:1.4504, average_loss: 1.2134
# Epoch [15/15], Iter [170,430] Loss:1.5957, average_loss: 1.2272
# Epoch [15/15], Iter [180,430] Loss:0.9715, average_loss: 1.2185
# Epoch [15/15], Iter [190,430] Loss:1.2879, average_loss: 1.2191
# Epoch [15/15], Iter [200,430] Loss:0.7837, average_loss: 1.2085
# Epoch [15/15], Iter [210,430] Loss:1.3350, average_loss: 1.2151
# Epoch [15/15], Iter [220,430] Loss:1.3252, average_loss: 1.2111
# Epoch [15/15], Iter [230,430] Loss:0.9417, average_loss: 1.2066
# Epoch [15/15], Iter [240,430] Loss:0.7085, average_loss: 1.2097
# Epoch [15/15], Iter [250,430] Loss:0.9728, average_loss: 1.2108
# Epoch [15/15], Iter [260,430] Loss:0.8553, average_loss: 1.2091
# Epoch [15/15], Iter [270,430] Loss:0.7783, average_loss: 1.2027
# Epoch [15/15], Iter [280,430] Loss:1.0577, average_loss: 1.1992
# Epoch [15/15], Iter [290,430] Loss:1.3374, average_loss: 1.2122
# Epoch [15/15], Iter [300,430] Loss:1.2416, average_loss: 1.2141
# Epoch [15/15], Iter [310,430] Loss:0.9774, average_loss: 1.2131
# Epoch [15/15], Iter [320,430] Loss:0.9929, average_loss: 1.2124
# Epoch [15/15], Iter [330,430] Loss:1.3528, average_loss: 1.2152
# Epoch [15/15], Iter [340,430] Loss:1.0419, average_loss: 1.2137
# Epoch [15/15], Iter [350,430] Loss:1.1067, average_loss: 1.2151
# Epoch [15/15], Iter [360,430] Loss:1.5346, average_loss: 1.2150
# Epoch [15/15], Iter [370,430] Loss:1.5204, average_loss: 1.2148
# Epoch [15/15], Iter [380,430] Loss:1.2139, average_loss: 1.2082
# Epoch [15/15], Iter [390,430] Loss:1.0418, average_loss: 1.2052
# Epoch [15/15], Iter [400,430] Loss:1.1658, average_loss: 1.2070
# Epoch [15/15], Iter [410,430] Loss:0.8254, average_loss: 1.2050
# Epoch [15/15], Iter [420,430] Loss:1.0739, average_loss: 1.2074
# Epoch [15/15], Iter [430,430] Loss:1.3193, average_loss: 1.2105

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from misc.lab07.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])
        
    img = np.zeros((h, w, 3), np.bool)
    img = img + image[:,:,::-1]
        
    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
    
    print(label)
    plt.imshow(img)
    
model.eval()
# Out:
# YOLO(
#   (pre_train_net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (16): LeakyReLU(negative_slope=0.01)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): LeakyReLU(negative_slope=0.01)
#     (19): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (20): LeakyReLU(negative_slope=0.01)
#     (21): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): LeakyReLU(negative_slope=0.01)
#     (23): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (24): LeakyReLU(negative_slope=0.01)
#     (25): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): LeakyReLU(negative_slope=0.01)
#     (27): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (28): LeakyReLU(negative_slope=0.01)
#     (29): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): LeakyReLU(negative_slope=0.01)
#     (31): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (32): LeakyReLU(negative_slope=0.01)
#     (33): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): LeakyReLU(negative_slope=0.01)
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (36): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (37): LeakyReLU(negative_slope=0.01)
#     (38): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): LeakyReLU(negative_slope=0.01)
#   )
#   (post_net): Sequential(
#     (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#   )
#   (FC1): Sequential(
#     (0): Linear(in_features=50176, out_features=4096, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (FC2): Sequential(
#     (0): Linear(in_features=4096, out_features=1470, bias=True)
#   )
# )

# %% [markdown]
# - You can check various results by chaning the name of files.

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004199.jpg')
# Out:
# aeroplane0.81

# %%
visualize(model, './misc/lab07/Generate_dataset/images/006034.jpg')
# Out:
# car0.95

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./misc/lab07/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 69.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 67.04% = aeroplane AP
# 67.61% = bicycle AP
# 65.31% = bus AP
# 68.68% = car AP
# 76.18% = cat AP
# 79.91% = dog AP
# mAP = 70.79%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP

# %% [markdown]
# YOLO는 1stage로 되어있어 속도에 있어 장점을 가지고 있다. 이번 실험을 통해서 그 속도를 확인할 수 있었는데,
#
# Visualization과 Inference에서 model에 이미지를 넣어 object를 detection데 있어, 우수한 성능을 보여주며 매우 빠른 속도로 처리되었다.
#
# YOLO는 가볍게 사용할 수 있는 모델이라 생각되며, 실시간 영상을 처리함에 있어 유용하게 사용될 수 있을  것 같다.
